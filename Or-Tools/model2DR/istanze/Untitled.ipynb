# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_excel('quadrato.xlsx')

# %%
print df.head()
# Out:
#    Square_index   Time       big  n_items
# 0      0.970000  0.145  2.946425        4
# 1      0.862000  0.177  2.229320        5
# 2      0.546667  0.053  3.250800        3
# 3      0.838000  0.745  4.001020        5
# 4      1.150000  1.311  5.008500        5

# %%
df.drop('Eu Obj', axis =1, inplace=True)
df.drop('Mod Obj', axis =1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-12fa50333181> in <module>()
# ----> 1 df.drop('Eu Obj', axis =1, inplace=True)
#       2 df.drop('Mod Obj', axis =1, inplace=True)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(df['Time'], df['n_items'], df['Avg_wd'])
threedee.set_xlabel('Time')
threedee.set_ylabel('n_items')
threedee.set_zlabel('M')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-6e83cded524f> in <module>()
#       1 threedee = plt.figure().gca(projection='3d')
# ----> 2 threedee.scatter(df['Time'], df['n_items'], df['Avg_wd'])
#       3 threedee.set_xlabel('Time')
#       4 threedee.set_ylabel('n_items')
#       5 threedee.set_zlabel('M')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
# ...
